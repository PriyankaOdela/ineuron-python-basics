# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\odela\\Downloads\\tested.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#dropna - doesnt drop permanently
# to solve we can override
1. df2 = df.dropna()

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#2
df.dropna(inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# df 0 means rows 1 means columns
df.dropna(axis = 1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#thresh - not na values
# age and cabin column doesnt have 400 non nan values ie it doesnt have 400 values that are not nan ie y the columns have dropped.
df.dropna(axis = 1,thresh = 400)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df.dropna(axis = 1,thresh = 400,how = 'all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                                Kelly, Mr. James    male      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female      1      0
# 2                       Myles, Mr. Thomas Francis    male      0      0
# 3                                Wirz, Mr. Albert    male      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female      1      1
# ..                                            ...     ...    ...    ...
# ...

# %%
df.fillna(value = df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df.groupby('Survived')

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                           \
#                count         mean         std    min     25%     50%      75%
# Survived
# 0              266.0  1102.620301  119.520499  892.0  999.25  1103.5  1203.75
# 1              152.0  1096.789474  123.345508  893.0  989.50  1093.5  1205.25
#
#                  Pclass            ... Parch        Fare             \
#              max  count      mean  ...   75%  max  count       mean
# Survived                           ...
# 0         1309.0  266.0  2.334586  ...   0.0  9.0  265.0  27.527877
# 1         1306.0  152.0  2.144737  ...   1.0  9.0  152.0  49.747699
#
#
#                 std   min      25%      50%      75%       max
# Survived
# 0         41.079423  0.00  7.85420  13.0000  26.5500  262.3750
# 1         73.108716  6.95  8.62605  21.5125  55.4417  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count         mean         std    min     25%     50%      75%  \
# Survived
# 0         266.0  1102.620301  119.520499  892.0  999.25  1103.5  1203.75
# 1         152.0  1096.789474  123.345508  893.0  989.50  1093.5  1205.25
#
#              max
# Survived
# 0         1309.0
# 1         1306.0

# %%
df.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived            0            1
# count      266.000000   152.000000
# mean      1102.620301  1096.789474
# std        119.520499   123.345508
# min        892.000000   893.000000
# 25%        999.250000   989.500000
# 50%       1103.500000  1093.500000
# 75%       1203.750000  1205.250000
# max       1309.000000  1306.000000

# %%
bank_data = pd.read_csv("C:\\Users\\odela\\Downloads\\bank.csv",sep = ";")

# %%
l= []
for i in bank_data['education'].unique():
    l.append(bank_data[bank_data['education'] == i])

# %%
df3 = l[0]

# %%
df3
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df4 = l[1]

# %%
df4
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
#concate
'sudh' + 'tur'
# Out:
# 'sudhtur'

# %%
#shape df3 and df4 is different
pd.concat([df3,df4])
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df3 = df3[:5]

# %%
df4 = df4.head(5)

# %%
df3
# Out:
#     age          job   marital education default  balance housing loan  \
# 0    30   unemployed   married   primary      no     1787      no   no
# 9    43     services   married   primary      no      -88     yes  yes
# 18   25  blue-collar    single   primary      no     -221     yes   no
# 26   55  blue-collar   married   primary      no      627     yes   no
# 36   78      retired  divorced   primary      no      229      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# 9    cellular   17   apr       313         1    147         2  failure   no
# 18    unknown   23   may       250         1     -1         0  unknown   no
# 26    unknown    5   may       247         1     -1         0  unknown   no
# 36  telephone   22   oct        97         1     -1         0  unknown  yes

# %%
df4
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
pd.concat([df3,df4])
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0    30   unemployed   married    primary      no     1787      no   no
# 9    43     services   married    primary      no      -88     yes  yes
# 18   25  blue-collar    single    primary      no     -221     yes   no
# 26   55  blue-collar   married    primary      no      627     yes   no
# 36   78      retired  divorced    primary      no      229      no   no
# 1    33     services   married  secondary      no     4789     yes  yes
# 4    59  blue-collar   married  secondary      no        0     yes   no
# 7    39   technician   married  secondary      no      147     yes   no
# 10   39     services   married  secondary      no     9374     yes   no
# 11   43       admin.   married  secondary      no      264     yes   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome    y
# 0    cellular   19   oct        79         1     -1         0  unknown   no
# ...

# %%
pd.concat([df3,df4],axis = 1)
# Out:
#      age          job   marital education default  balance housing loan  \
# 0   30.0   unemployed   married   primary      no   1787.0      no   no
# 9   43.0     services   married   primary      no    -88.0     yes  yes
# 18  25.0  blue-collar    single   primary      no   -221.0     yes   no
# 26  55.0  blue-collar   married   primary      no    627.0     yes   no
# 36  78.0      retired  divorced   primary      no    229.0      no   no
# 1    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 4    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 7    NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 10   NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
# 11   NaN          NaN       NaN       NaN     NaN      NaN     NaN  NaN
#
#       contact   day  ... loan   contact   day  month  duration campaign  \
# 0    cellular  19.0  ...  NaN       NaN   NaN    NaN       NaN      NaN
# ...

# %%
df3 =df3.head()[['age','job','education']]

# %%
df3
# Out:
#     age          job education
# 0    30   unemployed   primary
# 9    43     services   primary
# 18   25  blue-collar   primary
# 26   55  blue-collar   primary
# 36   78      retired   primary

# %%
df4 =df4.head()[['age','job','education']]

# %%
df4
# Out:
#     age          job  education
# 1    33     services  secondary
# 4    59  blue-collar  secondary
# 7    39   technician  secondary
# 10   39     services  secondary
# 11   43       admin.  secondary

# %%
df5 = pd.concat([df3,df4],axis = 1)

# %%
df5
# Out:
#      age          job education   age          job  education
# 0   30.0   unemployed   primary   NaN          NaN        NaN
# 9   43.0     services   primary   NaN          NaN        NaN
# 18  25.0  blue-collar   primary   NaN          NaN        NaN
# 26  55.0  blue-collar   primary   NaN          NaN        NaN
# 36  78.0      retired   primary   NaN          NaN        NaN
# 1    NaN          NaN       NaN  33.0     services  secondary
# 4    NaN          NaN       NaN  59.0  blue-collar  secondary
# 7    NaN          NaN       NaN  39.0   technician  secondary
# 10   NaN          NaN       NaN  39.0     services  secondary
# 11   NaN          NaN       NaN  43.0       admin.  secondary

# %%
df5.iloc[:,3]
# Out:
# 0      NaN
# 9      NaN
# 18     NaN
# 26     NaN
# 36     NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 10    39.0
# 11    43.0
# Name: age, dtype: float64

# %%
df5.loc[:,['age','education']]
# Out:
#      age   age education  education
# 0   30.0   NaN   primary        NaN
# 9   43.0   NaN   primary        NaN
# 18  25.0   NaN   primary        NaN
# 26  55.0   NaN   primary        NaN
# 36  78.0   NaN   primary        NaN
# 1    NaN  33.0       NaN  secondary
# 4    NaN  59.0       NaN  secondary
# 7    NaN  39.0       NaN  secondary
# 10   NaN  39.0       NaN  secondary
# 11   NaN  43.0       NaN  secondary

# %%
df5.iloc[9:,3]
# Out:
# 11    43.0
# Name: age, dtype: float64

# %%
df3
# Out:
#     age          job education
# 0    30   unemployed   primary
# 9    43     services   primary
# 18   25  blue-collar   primary
# 26   55  blue-collar   primary
# 36   78      retired   primary

# %%
df3.loc[[9,18],['job','age']]
# Out:
#             job  age
# 9      services   43
# 18  blue-collar   25

# %%
df3.iloc[1:3,[1,2]]
# Out:
#             job education
# 9      services   primary
# 18  blue-collar   primary

# %%
df3.loc[[9,18],['age','education']]
# Out:
#     age education
# 9    43   primary
# 18   25   primary

# %%
df3.iloc[[1,2],[0,2]]
# Out:
#     age education
# 9    43   primary
# 18   25   primary

# %%
df3
# Out:
#     age          job education
# 0    30   unemployed   primary
# 9    43     services   primary
# 18   25  blue-collar   primary
# 26   55  blue-collar   primary
# 36   78      retired   primary

# %%
df4
# Out:
#     age          job  education
# 1    33     services  secondary
# 4    59  blue-collar  secondary
# 7    39   technician  secondary
# 10   39     services  secondary
# 11   43       admin.  secondary

# %%
pd.merge(df3,df4,on = 'age')
# Out:
#    age     job_x education_x   job_y education_y
# 0   43  services     primary  admin.   secondary

# %%
pd.merge(df3,df4,on = 'job')
# Out:
#    age_x          job education_x  age_y education_y
# 0     43     services     primary     33   secondary
# 1     43     services     primary     39   secondary
# 2     25  blue-collar     primary     59   secondary
# 3     55  blue-collar     primary     59   secondary

# %%
pd.merge(df3,df4,on = 'age',how = 'left')
# Out:
#    age        job_x education_x   job_y education_y
# 0   30   unemployed     primary     NaN         NaN
# 1   43     services     primary  admin.   secondary
# 2   25  blue-collar     primary     NaN         NaN
# 3   55  blue-collar     primary     NaN         NaN
# 4   78      retired     primary     NaN         NaN

# %%
pd.merge(df3,df4,on = 'age',how = 'right')
# Out:
#    age     job_x education_x        job_y education_y
# 0   33       NaN         NaN     services   secondary
# 1   59       NaN         NaN  blue-collar   secondary
# 2   39       NaN         NaN   technician   secondary
# 3   39       NaN         NaN     services   secondary
# 4   43  services     primary       admin.   secondary

# %%
pd.merge(df3,df4,on = 'age',how = 'outer')
# Out:
#    age        job_x education_x        job_y education_y
# 0   30   unemployed     primary          NaN         NaN
# 1   43     services     primary       admin.   secondary
# 2   25  blue-collar     primary          NaN         NaN
# 3   55  blue-collar     primary          NaN         NaN
# 4   78      retired     primary          NaN         NaN
# 5   33          NaN         NaN     services   secondary
# 6   59          NaN         NaN  blue-collar   secondary
# 7   39          NaN         NaN   technician   secondary
# 8   39          NaN         NaN     services   secondary

# %%
df3
# Out:
#     age          job education
# 0    30   unemployed   primary
# 9    43     services   primary
# 18   25  blue-collar   primary
# 26   55  blue-collar   primary
# 36   78      retired   primary

# %%
df4
# Out:
#     age          job  education
# 1    33     services  secondary
# 4    59  blue-collar  secondary
# 7    39   technician  secondary
# 10   39     services  secondary
# 11   43       admin.  secondary

# %%
df3.set_index('age',inplace = True)

# %%
df4.set_index('age')
# Out:
#              job  education
# age
# 33      services  secondary
# 59   blue-collar  secondary
# 39    technician  secondary
# 39      services  secondary
# 43        admin.  secondary

# %%
df4.rename(columns = {"job":"job1","education":"education1"},inplace = True)

# %%
df4
# Out:
#     age         job1 education1
# 1    33     services  secondary
# 4    59  blue-collar  secondary
# 7    39   technician  secondary
# 10   39     services  secondary
# 11   43       admin.  secondary

# %%
df4.set_index('age',inplace = True)

# %%
df3.join(df4)
# Out:
#              job education    job1 education1
# age
# 25   blue-collar   primary     NaN        NaN
# 30    unemployed   primary     NaN        NaN
# 43      services   primary  admin.  secondary
# 55   blue-collar   primary     NaN        NaN
# 78       retired   primary     NaN        NaN

# %%
df3.join(df4,how = 'right')
# Out:
#           job education         job1 education1
# age
# 33        NaN       NaN     services  secondary
# 39        NaN       NaN   technician  secondary
# 39        NaN       NaN     services  secondary
# 43   services   primary       admin.  secondary
# 59        NaN       NaN  blue-collar  secondary

# %%
df3.join(df4,how = 'inner')
# Out:
#           job education    job1 education1
# age
# 43   services   primary  admin.  secondary

# %%
df3.join(df4,how = 'outer')
# Out:
#              job education         job1 education1
# age
# 25   blue-collar   primary          NaN        NaN
# 30    unemployed   primary          NaN        NaN
# 33           NaN       NaN     services  secondary
# 39           NaN       NaN   technician  secondary
# 39           NaN       NaN     services  secondary
# 43      services   primary       admin.  secondary
# 55   blue-collar   primary          NaN        NaN
# 59           NaN       NaN  blue-collar  secondary
# 78       retired   primary          NaN        NaN

# %%
df3.reset_index(inplace = True)

# %%
df3.age
# Out:
# 0    30
# 1    43
# 2    25
# 3    55
# 4    78
# Name: age, dtype: int64

# %%
df3['age']
# Out:
# 0    30
# 1    43
# 2    25
# 3    55
# 4    78
# Name: age, dtype: int64
