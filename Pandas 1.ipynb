# %%
 import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\odela\\Downloads\\tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.shape
# Out:
# (418, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.columns[df.dtypes == 'object']
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df['Age']
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
df['Age'].mean()
# Out:
# 30.272590361445783

# %%
cols = df.dtypes[df.dtypes == 'object'].index

# %%
cols
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[cols]
# Out:
#                                              Name     Sex              Ticket  \
# 0                                Kelly, Mr. James    male              330911
# 1                Wilkes, Mrs. James (Ellen Needs)  female              363272
# 2                       Myles, Mr. Thomas Francis    male              240276
# 3                                Wirz, Mr. Albert    male              315154
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female             3101298
# ..                                            ...     ...                 ...
# 413                            Spector, Mr. Woolf    male           A.5. 3236
# 414                  Oliva y Ocana, Dona. Fermina  female            PC 17758
# 415                  Saether, Mr. Simon Sivertsen    male  SOTON/O.Q. 3101262
# 416                           Ware, Mr. Frederick    male              359309
# 417                      Peter, Master. Michael J    male                2668
#
#     Cabin Embarked
# ...

# %%
df[cols].describe()
# Out:
#                     Name   Sex    Ticket            Cabin Embarked
# count                418   418       418               91      418
# unique               418     2       363               76        3
# top     Kelly, Mr. James  male  PC 17608  B57 B59 B63 B66        S
# freq                   1   266         5                3      270

# %%
#pandas proofling
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#adding new column
df['ineuron'] = "inner"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['Embarked']
# Out:
# 0      Q
# 1      S
# 2      Q
# 3      S
# 4      S
#       ..
# 413    S
# 414    C
# 415    S
# 416    S
# 417    C
# Name: Embarked, Length: 418, dtype: object

# %%
df[['Name','Embarked']]
# Out:
#                                              Name Embarked
# 0                                Kelly, Mr. James        Q
# 1                Wilkes, Mrs. James (Ellen Needs)        S
# 2                       Myles, Mr. Thomas Francis        Q
# 3                                Wirz, Mr. Albert        S
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)        S
# ..                                            ...      ...
# 413                            Spector, Mr. Woolf        S
# 414                  Oliva y Ocana, Dona. Fermina        C
# 415                  Saether, Mr. Simon Sivertsen        S
# 416                           Ware, Mr. Frederick        S
# 417                      Peter, Master. Michael J        C
#
# [418 rows x 2 columns]

# %%
df[:16]
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# ...

# %%
df.iloc[:16,3:5]
# Out:
#                                                  Name     Sex
# 0                                    Kelly, Mr. James    male
# 1                    Wilkes, Mrs. James (Ellen Needs)  female
# 2                           Myles, Mr. Thomas Francis    male
# 3                                    Wirz, Mr. Albert    male
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5                          Svensson, Mr. Johan Cervin    male
# 6                                Connolly, Miss. Kate  female
# 7                        Caldwell, Mr. Albert Francis    male
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9                             Davies, Mr. John Samuel    male
# 10                                   Ilieff, Mr. Ylio    male
# 11                         Jones, Mr. Charles Cresson    male
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 13                               Howard, Mr. Benjamin    male
# ...

# %%
df.loc[0]
# Out:
# PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# ineuron                   inner
# Name: 0, dtype: object

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413     True
# 414    False
# 415    False
# 416     True
# 417     True
# Name: Age, Length: 418, dtype: bool

# %%
df[df['Age'].isnull() == True].index
# Out:
# Int64Index([ 10,  22,  29,  33,  36,  39,  41,  47,  54,  58,  65,  76,  83,
#              84,  85,  88,  91,  93, 102, 107, 108, 111, 116, 121, 124, 127,
#             132, 133, 146, 148, 151, 160, 163, 168, 170, 173, 183, 188, 191,
#             199, 200, 205, 211, 216, 219, 225, 227, 233, 243, 244, 249, 255,
#             256, 265, 266, 267, 268, 271, 273, 274, 282, 286, 288, 289, 290,
#             292, 297, 301, 304, 312, 332, 339, 342, 344, 357, 358, 365, 366,
#             380, 382, 384, 408, 410, 413, 416, 417],
#            dtype='int64')

# %%
len(df[df['Age'].isnull() == True].index)
# Out:
# 86

# %%
df.loc[df[df['Age'].isnull() == True].index]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
#person name who paid highest fare
df['Fare'].max()
# Out:
# 512.3292

# %%
df[df['Fare'] == max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked ineuron
# 343      1  PC 17755  512.3292  B51 B53 B55        C   inner

# %% [markdown]
# # 1.How many male and female persons have onboadered?

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
df.value_counts('Sex')
# Out:
# Sex
# male      266
# female    152
# dtype: int64

# %%
len(df[df['Sex'] == 'male'])
# Out:
# 266

# %%
len(df[df['Sex'] == 'female'])
# Out:
# 152

# %%
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          152       152     152   152  127    152    152     152   152
# male            266       266     266   266  205    266    266     266   265
#
#         Cabin  Embarked  ineuron
# Sex
# female     44       152      152
# male       47       266      266

# %%
df.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    152
# male      266
# Name: Sex, dtype: int64

# %%
df['Sex'].size
# Out:
# 418

# %% [markdown]
# # 2.How many have survived?
# 1-survived
# 0-not survived

# %%
df.value_counts('Survived')
# Out:
# Survived
# 0    266
# 1    152
# dtype: int64

# %%
len(df[df['Survived'] == 1])
# Out:
# 152

# %% [markdown]
# # 3.How many casualities do we have?

# %%
len(df[df['Survived'] == 0])
# Out:
# 266

# %% [markdown]
# # 4.What is the name of person who is the eldest?

# %%
df[df['Age'] == df['Age'].max()]['Name']
# Out:
# 96    Cavendish, Mrs. Tyrell William (Julia Florence...
# Name: Name, dtype: object

# %% [markdown]
# # 5.How many persons do we have in first,second,third class?

# %%
df['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    107
# 2     93
# 3    218
# Name: Pclass, dtype: int64

# %% [markdown]
# # 6.How many people startswith 's'?

# %%
df['Name']
# Out:
# 0                                  Kelly, Mr. James
# 1                  Wilkes, Mrs. James (Ellen Needs)
# 2                         Myles, Mr. Thomas Francis
# 3                                  Wirz, Mr. Albert
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#                            ...
# 413                              Spector, Mr. Woolf
# 414                    Oliva y Ocana, Dona. Fermina
# 415                    Saether, Mr. Simon Sivertsen
# 416                             Ware, Mr. Frederick
# 417                        Peter, Master. Michael J
# Name: Name, Length: 418, dtype: object

# %%
df['Name'].str

# %%
df['Name'].str.startswith('S')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413     True
# 414    False
# 415     True
# 416    False
# 417    False
# Name: Name, Length: 418, dtype: bool

# %%
df[df['Name'].str.startswith('S')]
# Out:
#      PassengerId  Survived  Pclass  \
# 5            897         0       3
# 12           904         1       1
# 29           921         0       3
# 38           930         0       3
# 47           939         0       3
# 50           942         0       1
# 81           973         0       1
# 100          992         1       1
# 109         1001         0       2
# 110         1002         0       2
# 111         1003         1       3
# 114         1006         1       1
# 117         1009         1       3
# 122         1014         1       1
# 130         1022         0       3
# 137         1029         0       2
# 152         1044         0       3
# 160         1052         1       3
# 176         1068         1       2
# 177         1069         0       1
# 188         1080         1       3
# 191         1083         0       1
# 196         1088         0       1
# 230         1122         0       2
# 242         1134         0       1
# ...

# %%
len(df[df['Name'].str.startswith('S')])
# Out:
# 39

# %%
df[df['Name'].str.startswith('S')]['Name']
# Out:
# 5                             Svensson, Mr. Johan Cervin
# 12         Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 29                                     Samaan, Mr. Elias
# 38                                       Sap, Mr. Julius
# 47                              Shaughnessy, Mr. Patrick
# 50                              Smith, Mr. Lucien Philip
# 81                                    Straus, Mr. Isidor
# 100    Stengel, Mrs. Charles Emil Henry (Annie May Mo...
# 109                                    Swane, Mr. George
# 110                             Stanton, Mr. Samuel Ward
# 111                           Shine, Miss. Ellen Natalia
# 114               Straus, Mrs. Isidor (Rosalie Ida Blun)
# 117                      Sandstrom, Miss. Beatrice Irene
# 122                      Schabert, Mrs. Paul (Emma Mock)
# 130                              Spinner, Mr. Henry John
# 137                                  Schmidt, Mr. August
# ...

# %% [markdown]
# # 7.Create a new column which is summation of 'SibSp' and 'Parch'?

# %%
df['New'] = df['SibSp'] + df['Parch']

# %%
df['New']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      2
#       ..
# 413    0
# 414    0
# 415    0
# 416    0
# 417    2
# Name: New, Length: 418, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # 8.How many persons do we have age less than 25?

# %%
df[df['Age'] < 25]
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 5            897         0       3
# 8            900         1       3
# 9            901         0       3
# 12           904         1       1
# ..           ...       ...     ...
# 402         1294         1       1
# 403         1295         0       1
# 405         1297         0       2
# 406         1298         0       2
# 409         1301         1       3
#
#                                               Name     Sex   Age  SibSp  \
# 4     Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 5                       Svensson, Mr. Johan Cervin    male  14.0      0
# 8        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 9                          Davies, Mr. John Samuel    male  21.0      2
# 12   Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                             ...     ...   ...    ...
# ...

# %%
len(df[df['Age'] < 25])
# Out:
# 131

# %% [markdown]
# # 9.How many persons died whose age is less than 40?

# %%
df['Survived'] == 0
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 413     True
# 414    False
# 415     True
# 416     True
# 417     True
# Name: Survived, Length: 418, dtype: bool

# %%
df['Age'] < 40
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 413    False
# 414     True
# 415     True
# 416    False
# 417    False
# Name: Age, Length: 418, dtype: bool

# %%
(df['Survived'] == 0) & (df['Age'] < 40)
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 413    False
# 414    False
# 415     True
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
df[(df['Survived'] == 0) & (df['Age'] < 40)][['Survived','Age']]
# Out:
#      Survived   Age
# 0           0  34.5
# 3           0  27.0
# 5           0  14.0
# 7           0  26.0
# 9           0  21.0
# ..        ...   ...
# 401         0  38.0
# 403         0  17.0
# 405         0  20.0
# 406         0  23.0
# 415         0  38.5
#
# [153 rows x 2 columns]

# %%
len(df[(df['Survived'] == 0) & (df['Age'] < 40)])
# Out:
# 153

# %%
#cabin sep text and numeric
#regular expressions 
df['Cabin'] == 'Numeric'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Cabin, Length: 418, dtype: bool
