# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaOdela/ineuron-python-basics/blob/main/Pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # New section

# %%
df = pd.read_csv('/content/gapminder - gapminder.csv')

# %%
df.head()
# Out:
#    Unnamed: 0      country  year  population continent  life_exp       gdp_cap
# 0          11  Afghanistan  2007    31889923      Asia    43.828    974.580338
# 1          23      Albania  2007     3600523    Europe    76.423   5937.029526
# 2          35      Algeria  2007    33333216    Africa    72.301   6223.367465
# 3          47       Angola  2007    12420476    Africa    42.731   4797.231267
# 4          59    Argentina  2007    40301927  Americas    75.320  12779.379640

# %%
df.shape
# Out:
# (142, 7)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'year', 'population', 'continent', 'life_exp',
#        'gdp_cap'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# country        object
# year            int64
# population      int64
# continent      object
# life_exp      float64
# gdp_cap       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  142 non-null    int64
#  1   country     142 non-null    object
#  2   year        142 non-null    int64
#  3   population  142 non-null    int64
#  4   continent   142 non-null    object
#  5   life_exp    142 non-null    float64
#  6   gdp_cap     142 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 7.9+ KB

# %%
country_df = df['country']
country_df
# Out:
# 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                  Angola
# 4               Argentina
#               ...
# 137               Vietnam
# 138    West Bank and Gaza
# 139           Yemen, Rep.
# 140                Zambia
# 141              Zimbabwe
# Name: country, Length: 142, dtype: object

# %%
subset = df[['country','continent','year']]
subset
# Out:
#                 country continent  year
# 0           Afghanistan      Asia  2007
# 1               Albania    Europe  2007
# 2               Algeria    Africa  2007
# 3                Angola    Africa  2007
# 4             Argentina  Americas  2007
# ..                  ...       ...   ...
# 137             Vietnam      Asia  2007
# 138  West Bank and Gaza      Asia  2007
# 139         Yemen, Rep.      Asia  2007
# 140              Zambia    Africa  2007
# 141            Zimbabwe    Africa  2007
#
# [142 rows x 3 columns]

# %%
df.country
# Out:
# 0             Afghanistan
# 1                 Albania
# 2                 Algeria
# 3                  Angola
# 4               Argentina
#               ...
# 137               Vietnam
# 138    West Bank and Gaza
# 139           Yemen, Rep.
# 140                Zambia
# 141              Zimbabwe
# Name: country, Length: 142, dtype: object

# %%
df.shape[0]
# Out:
# 142

# %%
#loc
df.loc[0]
# Out:
# Unnamed: 0             11
# country       Afghanistan
# year                 2007
# population       31889923
# continent            Asia
# life_exp           43.828
# gdp_cap        974.580338
# Name: 0, dtype: object

# %%
df.loc[99]
# Out:
# Unnamed: 0           1199
# country          Paraguay
# year                 2007
# population        6667147
# continent        Americas
# life_exp           71.752
# gdp_cap       4172.838464
# Name: 99, dtype: object

# %%
df.shape
# Out:
# (142, 7)

# %%
# last row corrctly

# first value in shape represent rows we use first by position
row_index = df.shape[0]
last_row_index = row_index - 1
df.loc[last_row_index]
# Out:
# Unnamed: 0          1703
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 141, dtype: object

# %%
df.tail(n=1)
# Out:
#      Unnamed: 0   country  year  population continent  life_exp     gdp_cap
# 141        1703  Zimbabwe  2007    12311143    Africa    43.487  469.709298

# %%
df.head(n=1)
# Out:
#    Unnamed: 0      country  year  population continent  life_exp     gdp_cap
# 0          11  Afghanistan  2007    31889923      Asia    43.828  974.580338

# %%
type_loc = df.loc[0]
type_tail = df.tail(n=1)

# %%
type(type_loc)
# Out:
# pandas.core.series.Series

# %%
type(type_tail)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[[0,9,99]]
# Out:
#     Unnamed: 0      country  year  population continent  life_exp  \
# 0           11  Afghanistan  2007    31889923      Asia    43.828
# 9          119      Belgium  2007    10392226    Europe    79.441
# 99        1199     Paraguay  2007     6667147  Americas    71.752
#
#          gdp_cap
# 0     974.580338
# 9   33692.605080
# 99   4172.838464

# %%
df.iloc[1]
# Out:
# Unnamed: 0             23
# country           Albania
# year                 2007
# population        3600523
# continent          Europe
# life_exp           76.423
# gdp_cap       5937.029526
# Name: 1, dtype: object

# %%
df.iloc[-1]
# Out:
# Unnamed: 0          1703
# country         Zimbabwe
# year                2007
# population      12311143
# continent         Africa
# life_exp          43.487
# gdp_cap       469.709298
# Name: 141, dtype: object

# %%
subset = df.loc[:,['year','population']]
subset
# Out:
#      year  population
# 0    2007    31889923
# 1    2007     3600523
# 2    2007    33333216
# 3    2007    12420476
# 4    2007    40301927
# ..    ...         ...
# 137  2007    85262356
# 138  2007     4018332
# 139  2007    22211743
# 140  2007    11746035
# 141  2007    12311143
#
# [142 rows x 2 columns]

# %%
subset2 = df.iloc[:,[2,3,-1]]
subset2
# Out:
#      year  population       gdp_cap
# 0    2007    31889923    974.580338
# 1    2007     3600523   5937.029526
# 2    2007    33333216   6223.367465
# 3    2007    12420476   4797.231267
# 4    2007    40301927  12779.379640
# ..    ...         ...           ...
# 137  2007    85262356   2441.576404
# 138  2007     4018332   3025.349798
# 139  2007    22211743   2280.769906
# 140  2007    11746035   1271.211593
# 141  2007    12311143    469.709298
#
# [142 rows x 3 columns]

# %%
subset3 = df.loc[:,[2,3,-1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-5bb44f320a0a> in <module>
# ----> 1 subset3 = df.loc[:,[2,3,-1]]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
subset4 = df.iloc[:,['year','poppulation']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-1df268eb640e> in <module>
# ----> 1 subset4 = df.iloc[:,['year','poppulation']]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
range_subset = list(range(4))
subset5 = df.iloc[:,range_subset]

# %%
subset5
# Out:
#      Unnamed: 0             country  year  population
# 0            11         Afghanistan  2007    31889923
# 1            23             Albania  2007     3600523
# 2            35             Algeria  2007    33333216
# 3            47              Angola  2007    12420476
# 4            59           Argentina  2007    40301927
# ..          ...                 ...   ...         ...
# 137        1655             Vietnam  2007    85262356
# 138        1667  West Bank and Gaza  2007     4018332
# 139        1679         Yemen, Rep.  2007    22211743
# 140        1691              Zambia  2007    11746035
# 141        1703            Zimbabwe  2007    12311143
#
# [142 rows x 4 columns]

# %%
range_subset = list(range(2,6))
subset6 = df.iloc[:,range_subset]
subset6
# Out:
#      year  population continent  life_exp
# 0    2007    31889923      Asia    43.828
# 1    2007     3600523    Europe    76.423
# 2    2007    33333216    Africa    72.301
# 3    2007    12420476    Africa    42.731
# 4    2007    40301927  Americas    75.320
# ..    ...         ...       ...       ...
# 137  2007    85262356      Asia    74.249
# 138  2007     4018332      Asia    73.422
# 139  2007    22211743      Asia    62.698
# 140  2007    11746035    Africa    42.384
# 141  2007    12311143    Africa    43.487
#
# [142 rows x 4 columns]

# %%
range_subset = list(range(2,6,3))
subset7 = df.iloc[:,range_subset]
subset7
# Out:
#      year  life_exp
# 0    2007    43.828
# 1    2007    76.423
# 2    2007    72.301
# 3    2007    42.731
# 4    2007    75.320
# ..    ...       ...
# 137  2007    74.249
# 138  2007    73.422
# 139  2007    62.698
# 140  2007    42.384
# 141  2007    43.487
#
# [142 rows x 2 columns]

# %%
small_range = list(range(5))
subset7 = df.iloc[:,small_range]
subset7
# Out:
#      Unnamed: 0             country  year  population continent
# 0            11         Afghanistan  2007    31889923      Asia
# 1            23             Albania  2007     3600523    Europe
# 2            35             Algeria  2007    33333216    Africa
# 3            47              Angola  2007    12420476    Africa
# 4            59           Argentina  2007    40301927  Americas
# ..          ...                 ...   ...         ...       ...
# 137        1655             Vietnam  2007    85262356      Asia
# 138        1667  West Bank and Gaza  2007     4018332      Asia
# 139        1679         Yemen, Rep.  2007    22211743      Asia
# 140        1691              Zambia  2007    11746035    Africa
# 141        1703            Zimbabwe  2007    12311143    Africa
#
# [142 rows x 5 columns]

# %%
df.iloc[:,0:6:]
# Out:
#      Unnamed: 0             country  year  population continent  life_exp
# 0            11         Afghanistan  2007    31889923      Asia    43.828
# 1            23             Albania  2007     3600523    Europe    76.423
# 2            35             Algeria  2007    33333216    Africa    72.301
# 3            47              Angola  2007    12420476    Africa    42.731
# 4            59           Argentina  2007    40301927  Americas    75.320
# ..          ...                 ...   ...         ...       ...       ...
# 137        1655             Vietnam  2007    85262356      Asia    74.249
# 138        1667  West Bank and Gaza  2007     4018332      Asia    73.422
# 139        1679         Yemen, Rep.  2007    22211743      Asia    62.698
# 140        1691              Zambia  2007    11746035    Africa    42.384
# 141        1703            Zimbabwe  2007    12311143    Africa    43.487
#
# [142 rows x 6 columns]

# %%
df.shape
# Out:
# (142, 7)

# %%
#groped and aggregated
group_by_year = df.groupby('year')
group_by_year

# %%
group_by_year_life = group_by_year['life_exp']

# %%
mean_group_by_year_life = group_by_year_life.mean()
mean_group_by_year_life
# Out:
# year
# 2007    67.007423
# Name: life_exp, dtype: float64

# %%
#multi var grouping
multi_var = df.groupby(['year','continent'])[['life_exp','population']].mean()
multi_var
# Out:
#                  life_exp    population
# year continent
# 2007 Africa     54.806038  1.787576e+07
#      Americas   73.608120  3.595485e+07
#      Asia       70.728485  1.155138e+08
#      Europe     77.648600  1.953662e+07
#      Oceania    80.719500  1.227497e+07

# %%
multi_var.reset_index()
# Out:
#    year continent   life_exp    population
# 0  2007    Africa  54.806038  1.787576e+07
# 1  2007  Americas  73.608120  3.595485e+07
# 2  2007      Asia  70.728485  1.155138e+08
# 3  2007    Europe  77.648600  1.953662e+07
# 4  2007   Oceania  80.719500  1.227497e+07

# %%
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
df.groupby('continent')['country'].value_counts()
# Out:
# continent  country
# Africa     Algeria           1
#            Angola            1
#            Benin             1
#            Botswana          1
#            Burkina Faso      1
#                             ..
# Europe     Switzerland       1
#            Turkey            1
#            United Kingdom    1
# Oceania    Australia         1
#            New Zealand       1
# Name: country, Length: 142, dtype: int64

# %%
import matplotlib.pyplot as plt
group_by_year_life.plot()
plt.show()
