# %%
import pandas as pd

# %%
pd.read_csv("C:\\Users\\odela\\Downloads\\bank.csv")
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
bank_data = pd.read_csv("C:\\Users\\odela\\Downloads\\bank.csv",sep = ";")

# %%
bank_data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# # 1.How many campaign available in the dataset?

# %%
bank_data['campaign'].value_counts()
# Out:
# 1     1734
# 2     1264
# 3      558
# 4      325
# 5      167
# 6      155
# 7       75
# 8       56
# 9       30
# 10      27
# 11      22
# 12      21
# 13      17
# 14      10
# 15       9
# 16       8
# 17       7
# 18       7
# 25       4
# 19       3
# 20       3
# 28       3
# 24       3
# 32       2
# 21       2
# 23       2
# 22       2
# 31       1
# 29       1
# 50       1
# 30       1
# 44       1
# Name: campaign, dtype: int64

# %%
len(bank_data['campaign'])
# Out:
# 4521

# %%
bank_data['campaign'].unique()
# Out:
# array([ 1,  4,  2,  5,  3,  6, 18, 10,  9,  7, 12, 14, 13, 24, 11,  8, 29,
#        32, 16, 22, 15, 30, 25, 21, 17, 19, 23, 20, 50, 28, 31, 44],
#       dtype=int64)

# %%
len(bank_data['campaign'].unique())
# Out:
# 32

# %% [markdown]
# # 2.Howmany users do we have with housing and personal loan?

# %%
bank_data['housing'] == 'yes'
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 4516     True
# 4517     True
# 4518    False
# 4519    False
# 4520     True
# Name: housing, Length: 4521, dtype: bool

# %%
bank_data.groupby('housing')['housing'].count()
# Out:
# housing
# no     1962
# yes    2559
# Name: housing, dtype: int64

# %%
bank_data['loan'] == 'yes'
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 4516    False
# 4517     True
# 4518    False
# 4519    False
# 4520     True
# Name: loan, Length: 4521, dtype: bool

# %%
bank_data[(bank_data['housing'] == 'yes') & (bank_data['loan'] == 'yes')]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 1      33       services  married  secondary      no     4789     yes  yes
# 3      30     management  married   tertiary      no     1476     yes  yes
# 9      43       services  married    primary      no      -88     yes  yes
# 14     31    blue-collar  married  secondary      no      360     yes  yes
# 48     32   entrepreneur   single    primary     yes     -849     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4502   42       services  married  secondary      no      -91     yes  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
# 4508   42         admin.  married    unknown      no      642     yes  yes
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
len(bank_data[(bank_data['housing'] == 'yes') & (bank_data['loan'] == 'yes')])
# Out:
# 406

# %% [markdown]
# # 3.How many persons do we have whose age is 60+ ?

# %%
bank_data[bank_data['age'] > 60]
# Out:
#       age         job   marital  education default  balance housing loan  \
# 27     67     retired   married    unknown      no      696      no   no
# 30     68     retired  divorced  secondary      no     4189      no   no
# 36     78     retired  divorced    primary      no      229      no   no
# 49     61      admin.   married    unknown      no     4629     yes   no
# 61     63     retired   married  secondary      no      415     yes   no
# ...   ...         ...       ...        ...     ...      ...     ...  ...
# 4337   73     retired   married    unknown      no      519      no   no
# 4364   63     retired  divorced  secondary      no     1490      no   no
# 4388   83     retired  divorced    primary      no     1097      no   no
# 4413   65     retired   married    primary      no      493      no   no
# 4466   61  management   married  secondary      no      967      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
len(bank_data[bank_data['age'] > 60 ])
# Out:
# 127

# %% [markdown]
# # 4.In which month we have targeted most of customers?

# %%
bank_data['month'].value_counts()
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
bank_data['month'].value_counts().index[0]
# Out:
# 'may'

# %% [markdown]
# # 5.Which mode of contact is giving more results?

# %%
bank_data['contact'].value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
bank_data['contact'].value_counts().index[0]
# Out:
# 'cellular'

# %%
contact_group = bank_data.groupby(['contact','y'])['contact'].count()

# %%
contact_group.loc['cellular','yes']
# Out:
# 416

# %%
contact_group.loc['unknown','yes']
# Out:
# 61

# %%
contact_group.loc['telephone','yes']
# Out:
# 44

# %%
max(contact_group.loc['cellular','yes'],contact_group.loc['cellular','yes'],contact_group.loc['telephone','yes'])
# Out:
# 416

# %% [markdown]
# # 6.How many enterpreneur?

# %%
bank_data['job'].value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
bank_data['job'] == 'entrepreneur'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520     True
# Name: job, Length: 4521, dtype: bool

# %%
bank_data[bank_data['job'] == 'entrepreneur']
# Out:
#       age           job   marital  education default  balance housing loan  \
# 8      41  entrepreneur   married   tertiary      no      221     yes   no
# 23     44  entrepreneur   married  secondary      no       93      no   no
# 48     32  entrepreneur    single    primary     yes     -849     yes  yes
# 71     42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 150    41  entrepreneur   married    unknown      no       89     yes   no
# ...   ...           ...       ...        ...     ...      ...     ...  ...
# 4401   38  entrepreneur  divorced   tertiary      no     7929      no   no
# 4402   41  entrepreneur   married    primary      no       39     yes   no
# 4487   49  entrepreneur  divorced  secondary      no       32      no   no
# 4497   31  entrepreneur    single   tertiary      no       38      no   no
# 4520   44  entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
len(bank_data[bank_data['job'] == 'entrepreneur'])
# Out:
# 168

# %% [markdown]
# # 7.How many customers do we have with negative balance?

# %%
bank_data['balance'].value_counts()
# Out:
# 0       357
# 2        24
# 1        15
# 4        13
# 5        11
#        ...
# 539       1
# 1041      1
# 464       1
# 7702      1
# 1137      1
# Name: balance, Length: 2353, dtype: int64

# %%
bank_data[bank_data['balance'] < 0]['balance']
# Out:
# 9        -88
# 18      -221
# 48      -849
# 60      -516
# 92      -195
#         ...
# 4474    -237
# 4502     -91
# 4506    -166
# 4516    -333
# 4517   -3313
# Name: balance, Length: 366, dtype: int64

# %%
len(bank_data[bank_data['balance'] < 0])
# Out:
# 366

# %% [markdown]
# # 8.Prepare group of data based on education.

# %%
bank_data['education'].value_counts()
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
bank_data.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
bank_data[bank_data['education'] == 'primary']['education'].count()
# Out:
# 678

# %%
bank_data[bank_data['education'] == 'secondary']['education'].count()
# Out:
# 2306

# %%
bank_data[bank_data['education'] == 'tertiary']['education'].count()
# Out:
# 1350

# %%
bank_data['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
l= []
for i in bank_data['education'].unique():
    l.append(bank_data[bank_data['education'] == i])

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...
